# %% [markdown]
# # Political Party Prediction using Deep Neural Networks

# %% [markdown]
# ## Introduction
# This project aims to predict policitial party affiliation based on their votes using deep neural networks. We will leverage modern machine learning libraries and techniques to achieve accurate predictions.

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
feature_names = ['party', 'handicapped-infants', 'water-projet-cost-sharing', 'adoption-of-the-budget-resolution', 
                 'physician-fee-freeze', 'el-salcador-aid', 'religious-groups-in-schools', 'anti-satellite-test-ban',
                 'aid-to-nicaragaun-contras', 'mx-missle', 'immigration', 'synfuels-corporation-curback', 'education-spending',
                 'superfund-rigth-to-sue', 'crime', 'duty-free-exports', 'export-administration-act-south-africa']

voting_data = pd.read_csv('house-votes-84.data.txt', na_values = ['?'], names = feature_names)
voting_data.head()
# Out:
#         party handicapped-infants water-projet-cost-sharing  \
# 0  republican                   n                         y
# 1  republican                   n                         y
# 2    democrat                 NaN                         y
# 3    democrat                   n                         y
# 4    democrat                   y                         y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salcador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                  NaN               y
# 3                                 y                    n             NaN
# 4                                 y                    n               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# 1                           y                       n
# 2                           y                       n
# 3                           y                       n
# 4                           y                       n
#
#   aid-to-nicaragaun-contras mx-missle immigration  \
# 0                         n         n           y
# 1                         n         n           n
# 2                         n         n           n
# 3                         n         n           n
# 4                         n         n           n
#
#   synfuels-corporation-curback education-spending superfund-rigth-to-sue  \
# 0                          NaN                  y                      y
# 1                            n                  y                      y
# 2                            y                  n                      y
# 3                            y                  n                      y
# 4                            y                NaN                      y
#
#   crime duty-free-exports export-administration-act-south-africa
# 0     y                 n                                      y
# 1     y                 n                                    NaN
# 2     y                 n                                      n
# 3     n                 n                                      y
# 4     y                 y                                      y

# %%
# describing the data
voting_data.describe()
# Out:
#            party handicapped-infants water-projet-cost-sharing  \
# count        435                 423                       387
# unique         2                   2                         2
# top     democrat                   n                         y
# freq         267                 236                       195
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salcador-aid  \
# count                                424                  424             420
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 253                  247             212
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          424                     421
# unique                           2                       2
# top                              y                       y
# freq                           272                     239
#
#        aid-to-nicaragaun-contras mx-missle immigration  \
# count                        420       413         428
# unique                         2         2           2
# top                            y         y           y
# freq                         242       207         216
#
#        synfuels-corporation-curback education-spending superfund-rigth-to-sue  \
# count                           414                404                    410
# unique                            2                  2                      2
# top                               n                  n                      y
# freq                            264                233                    209
#
#        crime duty-free-exports export-administration-act-south-africa
# count    418               407                                    331
# unique     2                 2                                      2
# top        y                 n                                      y
# freq     248               233                                    269

# %%
# shape of data
voting_data.shape
# Out:
# (435, 17)

# %% [markdown]
# ### Handling missing values

# %%
voting_data.dropna(inplace = True)
voting_data.describe()
# Out:
#            party handicapped-infants water-projet-cost-sharing  \
# count        232                 232                       232
# unique         2                   2                         2
# top     democrat                   n                         n
# freq         124                 136                       125
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salcador-aid  \
# count                                232                  232             232
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 123                  119             128
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          232                     232
# unique                           2                       2
# top                              y                       y
# freq                           149                     124
#
#        aid-to-nicaragaun-contras mx-missle immigration  \
# count                        232       232         232
# unique                         2         2           2
# top                            y         n           y
# freq                         119       119         128
#
#        synfuels-corporation-curback education-spending superfund-rigth-to-sue  \
# count                           232                232                    232
# unique                            2                  2                      2
# top                               n                  n                      y
# freq                            152                124                    127
#
#        crime duty-free-exports export-administration-act-south-africa
# count    232               232                                    232
# unique     2                 2                                      2
# top        y                 n                                      y
# freq     149               146                                    189

# %% [markdown]
# ### Normalizing the data

# %%
# normalizing the data
voting_data.replace(('y','n'),(1,0),inplace = True)
voting_data.replace(('democrat','republican'),(1,0),inplace = True)

# %%
voting_data.head()
# Out:
#     party  handicapped-infants  water-projet-cost-sharing  \
# 5       1                    0                          1
# 8       0                    0                          1
# 19      1                    1                          1
# 23      1                    1                          1
# 25      1                    1                          0
#
#     adoption-of-the-budget-resolution  physician-fee-freeze  el-salcador-aid  \
# 5                                   1                     0                1
# 8                                   0                     1                1
# 19                                  1                     0                0
# 23                                  1                     0                0
# 25                                  1                     0                0
#
#     religious-groups-in-schools  anti-satellite-test-ban  \
# 5                             1                        0
# 8                             1                        0
# 19                            0                        1
# 23                            0                        1
# 25                            0                        1
#
#     aid-to-nicaragaun-contras  mx-missle  immigration  \
# 5                           0          0            0
# 8                           0          0            0
# 19                          1          1            0
# 23                          1          1            0
# 25                          1          1            1
#
#     synfuels-corporation-curback  education-spending  superfund-rigth-to-sue  \
# 5                              0                   0                       1
# 8                              0                   1                       1
# 19                             1                   0                       0
# 23                             0                   0                       0
# 25                             0                   0                       0
#
#     crime  duty-free-exports  export-administration-act-south-africa
# 5       1                  1                                       1
# 8       1                  0                                       1
# 19      0                  1                                       1
# 23      0                  1                                       1
# 25      0                  1                                       1

# %% [markdown]
# ## Feature Extraction

# %%
# extracting input features
all_features = voting_data[feature_names].drop('party',axis = 1).values

# extracting target classes
all_classes = voting_data['party'].values

# %% [markdown]
# ## Model Architecture

# %%
# defining the neural network model
def create_model():
    model = Sequential()
    model.add(Dense(32, input_dim = 16,kernel_initializer = 'normal',activation='relu'))
    model.add(Dense(16,kernel_initializer ='normal',activation = 'relu'))
    model.add(Dense(1,kernel_initializer ='normal',activation ='sigmoid'))
    model.compile(loss = 'binary_crossentropy',optimizer ='adam',metrics = ['accuracy'])
    return model

# %% [markdown]
# ## Cross-Validation and Model Evaluation

# %%
# defining cros-validation strategy
cv = StratifiedKFold(n_splits = 10,shuffle = True,random_state = 42)

# creating a KerasClassifier
estimator = KerasClassifier(build_fn = create_model,epochs = 100,verbose = 0)

# perform cross-validation
cv_scores = cross_val_score(estimator,all_features,all_classes,cv = cv)
cv_scores.mean()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2472\345769444.py:5: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasClassifier(build_fn = create_model,epochs = 100,verbose = 0)
# 0.9485507309436798

# %% [markdown]
# Through the utilization of advanced deep neural networks and meticulous cross-validation methodologies, we successfully predict political party affiliation based on voting data. The obtained mean accuracy provides insight into the model's predictive capabilities on unseen data.
